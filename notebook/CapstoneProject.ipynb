# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import re

# %%
df = pd.read_csv('../data/Rates_and_Trends_in_Heart_Disease.csv')
# Out:
# C:\Users\adisu\AppData\Local\Temp\ipykernel_38580\4217082028.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/Rates_and_Trends_in_Heart_Disease.csv')

# %%
df
# Out:
#                 Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 0               1999           AL      Autauga          County       NVSS
# 1               2013           AL      Autauga          County       NVSS
# 2               2014           AL      Autauga          County       NVSS
# 3               2005           AL      Autauga          County       NVSS
# 4               2012           AL      Autauga          County       NVSS
# ...              ...          ...          ...             ...        ...
# 5770235  1999 - 2010           WY       Weston          County       NVSS
# 5770236  2010 - 2019           WY       Weston          County       NVSS
# 5770237  1999 - 2010           WY       Weston          County       NVSS
# 5770238  1999 - 2010           WY       Weston          County       NVSS
# 5770239  2010 - 2019           WY       Weston          County       NVSS
#
#                            Class                         Topic  Data_Value  \
# ...

# %%
df.drop('Data_Value_Footnote_Symbol', axis =1, inplace =True)

# %%
df.loc[df['Year']] == 2012
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.loc[df['Year']] == 2012
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1322, in _LocIndexer._getitem_iterable(self, key, axis)
# ...

# %%
filtered_df = df.query("Year >= '2001' & Year <= '2010'")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 filtered_df = df.query("Year >= '2001' & Year <= '2010'")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4602, in DataFrame.query(self, expr, inplace, **kwargs)
#    4600 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4601 kwargs["target"] = None
# -> 4602 res = self.eval(expr, **kwargs)
#    4604 try:
#    4605     result = self.loc[res]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4728, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4725     kwargs["target"] = self
#    4726 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4728 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
# ...

# %%
result = df.query("Year == '2010'")
result
# Out:
#          Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 5210113  2010           WI       Taylor          County       NVSS
# 5210136  2010           WI       Taylor          County       NVSS
# 5210162  2010           WI       Taylor          County       NVSS
# 5210178  2010           WI       Taylor          County       NVSS
# 5210199  2010           WI       Taylor          County       NVSS
# ...       ...          ...          ...             ...        ...
# 5268395  2010           WY       Weston          County       NVSS
# 5268418  2010           WY       Weston          County       NVSS
# 5268441  2010           WY       Weston          County       NVSS
# 5268458  2010           WY       Weston          County       NVSS
# 5268480  2010           WY       Weston          County       NVSS
#
#                            Class                         Topic  Data_Value  \
# 5210113  Cardiovascular Diseases             All heart disease         NaN
# ...

# %%
df2 = df.loc[df['LocationAbbr'] == 'RI']

# %%
df2.loc[df2['LocationDesc'] == 'Bristol']
# Out:
#                 Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 3871678         2009           RI      Bristol          County       NVSS
# 3871735         2002           RI      Bristol          County       NVSS
# 3872102         2003           RI      Bristol          County       NVSS
# 3872268         2006           RI      Bristol          County       NVSS
# 3872404         1999           RI      Bristol          County       NVSS
# ...              ...          ...          ...             ...        ...
# 5637452  1999 - 2010           RI      Bristol          County       NVSS
# 5637453  2010 - 2019           RI      Bristol          County       NVSS
# 5637454  1999 - 2010           RI      Bristol          County       NVSS
# 5637455  1999 - 2010           RI      Bristol          County       NVSS
# 5637456  2010 - 2019           RI      Bristol          County       NVSS
#
#                            Class                         Topic  Data_Value  \
# ...

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0                 1999
# 1                 2013
# 2                 2014
# 3                 2005
# 4                 2012
#               ...
# 5770235    1999 - 2010
# 5770236    2010 - 2019
# 5770237    1999 - 2010
# 5770238    1999 - 2010
# 5770239    2010 - 2019
# Name: Year, Length: 5770240, dtype: object>

# %%
df['Year'].str.extract(r'(\d{4})')
# Out:
#             0
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 5770235  1999
# 5770236  2010
# 5770237  1999
# 5770238  1999
# 5770239  2010
#
# [5770240 rows x 1 columns]

# %%
### df['Year'] = pd.to_datetime(df['Year'], format='%y')
